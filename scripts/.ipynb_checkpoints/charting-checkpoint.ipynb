# %%
# !ls
# Out:
# agg.ipynb  devangari.ipynb    scratchpad_lab_modified.py
# agg.py	   predictions.ipynb

# %%
import os
path = "../output"
os.listdir(path)
# Out:
# ['passengers_D_df.csv',
#  'passengers_I_df.csv',
#  'movement_I_df.csv',
#  'freight_D_df.csv',
#  'movement_D_df.csv',
#  'freight_I_df.csv']

# %%
import pandas as pd
file = 'freight_I_df.csv'
filepath = path+'/'+file
df = pd.read_csv(filepath, index_col=0)
df.head()
# Out:
#         EASTERN  NORTH EAST  NORTHERN  SOUTHERN  WESTERN
# 201600     3551           2     41211     45160    40337
# 201601     3616           0     39456     47792    43736
# 201602     4376           1     45229     57045    49737
# 201603     4096           0     44097     51760    44509
# 201604     4518           0     48717     53486    46230

# %%
# df.index

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.plot(df.index, df['EASTERN'] )
plt.plot(df.index, df['WESTERN'] )
plt.plot(df.index, df['NORTHERN'] )
plt.plot(df.index, df['NORTH EAST'] )

plt.plot(df.index, df['SOUTHERN'] )


plt.show()
